# %%
odd_numbers =[1,3,5,7,9]

squares = list(map(lambda x: x**2,odd_numbers))

print(squares)
# Out:
# [1, 9, 25, 49, 81]

# %%
# Function to check if a number is prime
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

# Given list of numbers
numbers = [10, 17, 23, 42, 59, 84, 97]

# Use filter to get prime numbers
prime_numbers = list(filter(is_prime, numbers))

print("Prime numbers:", prime_numbers)
# Out:
# Prime numbers: [17, 23, 59, 97]

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/Punith Harshitha/Desktop/mtcars.csv")

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())
print()

# Get a concise summary of the dataset
print("Dataset Info:")
print(df.info())
print()

# Generate summary statistics
print("Summary Statistics:")
print(df.describe())
print()

# Check for missing values
print("Missing Values in Each Column:")
print(df.isnull().sum())
print()

# Check data types of each column
print("Data Types of Each Column:")
print(df.dtypes)
print()

# List unique values for categorical columns (if any)
categorical_columns = df.select_dtypes(include=['object']).columns
if categorical_columns.size > 0:
    print("Unique Values in Categorical Columns:")
    for column in categorical_columns:
        print(f"{column}:")
        print(df[column].value_counts())
        print()
else:
    print("No categorical columns found.")
# Out:
# First few rows of the dataset:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
df = pd.read_csv("C:/Users/Punith Harshitha/Desktop/mtcars.csv")

# Plot the histogram for the 'mpg' column
plt.hist(df['mpg'], bins=10, edgecolor='black')
plt.title('Histogram of MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Define the number of bins
bins = 10

# Calculate histogram values
counts, bin_edges = np.histogram(df['mpg'], bins=bins)

# Find the interval with the highest frequency
max_count_index = np.argmax(counts)
highest_interval = (bin_edges[max_count_index], bin_edges[max_count_index + 1])

print(f"Interval with the highest frequency: {highest_interval}")
print(f"Frequency of this interval: {counts[max_count_index]}")
# Out:
# Interval with the highest frequency: (15.100000000000001, 17.450000000000003)
# Frequency of this interval: 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:/Users/Punith Harshitha/Desktop/mtcars.csv")

# Scatter plot of MPG vs. Horsepower
plt.figure(figsize=(10, 6))
plt.scatter(df['hp'], df['mpg'], color='blue', alpha=0.7)
plt.title('Scatter Plot of MPG vs. Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('Miles Per Gallon (MPG)')
plt.grid(True)
plt.show()

# Scatter plot of MPG vs. Weight
plt.figure(figsize=(10, 6))
plt.scatter(df['wt'], df['mpg'], color='green', alpha=0.7)
plt.title('Scatter Plot of MPG vs. Weight')
plt.xlabel('Weight')
plt.ylabel('Miles Per Gallon (MPG)')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:/Users/Punith Harshitha/Desktop/mtcars.csv")

# Map transmission type for better readability
df['transmission'] = df['am'].map({0: 'Automatic', 1: 'Manual'})

# Count the frequency of each transmission type
transmission_counts = df['transmission'].value_counts()

# Plot the bar plot
plt.figure(figsize=(8, 5))
transmission_counts.plot(kind='bar', color=['blue', 'orange'], edgecolor='black')
plt.title('Frequency Distribution of Transmission Types')
plt.xlabel('Transmission Type')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # Rotate x-axis labels to horizontal
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:/Users/Punith Harshitha/Desktop/mtcars.csv")

# Create a box plot for the 'mpg' column
plt.figure(figsize=(8, 6))
plt.boxplot(df['mpg'], vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightblue', color='black'), 
            whiskerprops=dict(color='black'), 
            capprops=dict(color='black'), 
            medianprops=dict(color='red'))
plt.title('Box Plot of MPG')
plt.xlabel('Miles Per Gallon (MPG)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Calculate the five-number summary
min_val = df['mpg'].min()
q1 = df['mpg'].quantile(0.25)
median = df['mpg'].median()
q3 = df['mpg'].quantile(0.75)
max_val = df['mpg'].max()

# Print the five-number summary
print(f"Minimum: {min_val}")
print(f"First Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"Third Quartile (Q3): {q3}")
print(f"Maximum: {max_val}")
# Out:
# Minimum: 10.4
# First Quartile (Q1): 15.425
# Median (Q2): 19.2
# Third Quartile (Q3): 22.8
# Maximum: 33.9
